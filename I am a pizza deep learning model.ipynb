# %%
pip --version
# Out:
# pip 24.1.2 from /opt/anaconda3/lib/python3.11/site-packages/pip (python 3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 \
import preprocess_input
from tensorflow.keras.applications.resnet50 \
import decode_predictions

# %%
mymodel = ResNet50()

# %%
myimage = load_img('/Users/alexandriahamilton/im1.jpg', \
                   target_size=(224, 224))

# %%
myimage
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
myimage = img_to_array(myimage)

# %%
myimage = myimage.reshape((1, 224, 224, 3))

# %%
myimage = preprocess_input(myimage)

# %%
myresult = mymodel.predict(myimage)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step

# %%
mylabel = decode_predictions(myresult)

# %%
mylabel = mylabel[0][0]

# %%
print("This is a : " + mylabel[1])
# Out:
# This is a : pizza

# %%
sayit="This is a "+mylabel[1]

# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
import os

# Create the text-to-speech object
tts = gTTS(text="This is a pizza.", lang='en')

# Save the audio to a file
tts.save("/Users/alexandriahamilton/prediction.mp3")

# %%
from IPython.display import Audio

# Display the audio file in Jupyter
Audio("/Users/alexandriahamilton/prediction.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
